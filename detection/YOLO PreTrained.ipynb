# %%
from gluoncv import model_zoo, data, utils
from matplotlib import pyplot as plt
from matplotlib import rcParams

# %%
rcParams['figure.figsize'] = 10, 10

# %%
net = model_zoo.get_model('yolo3_darknet53_voc', pretrained=True)
# Out:
# Model file is not found. Downloading.
# Downloading /home/amitosh/.mxnet/models/yolo3_darknet53_voc-f5ece5ce.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/yolo3_darknet53_voc-f5ece5ce.zip...
# 223070KB [02:30, 1480.19KB/s]

# %%
x, img = data.transforms.presets.ssd.load_test('/home/amitosh/Downloads/IMG_20181111_150902.jpg', short=512)
print('Shape of pre-processed image:', x.shape)
# Out:
# Shape of pre-processed image: (1, 3, 910, 512)

# %%
class_IDs, scores, bounding_boxs = net(x)

ax = utils.viz.plot_bbox(img, bounding_boxs[0], scores[0],
                         class_IDs[0], class_names=net.classes, )

plt.show()
